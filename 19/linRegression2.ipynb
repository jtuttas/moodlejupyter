# %% [markdown]
# # Importieren der verwendeten Bibliotheken und Einlesen des Datensatzes

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

d = pd.read_csv("./Data/bo.csv")
df = pd.DataFrame(d)
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# ## Bedeutung der Spalten
#
# - CRIM: Kriminalitätsrate pro Kopf
# - ZN: Anteil der Wohngrundstücke über 25.000 Quadratfuß
# - INDUS: Anteil der Nicht-Einzelhandels-Geschäftsflächen pro Stadt
# - CHAS: Charles River-Dummy-Variable (1, falls das Grundstück an einem Fluss liegt, sonst 0)
# - NOX: Stickoxidkonzentration (in Teilen pro 10 Millionen)
# - RM: Durchschnittliche Anzahl von Zimmern pro Wohnung
# - AGE: Anteil der im Jahr 1940 oder früher errichteten Wohnungen
# - DIS: Gewichteter Abstand zu fünf Bostoner Arbeitszentren
# - RAD: Index der Zugänglichkeit zu radialen Autobahnen
# - TAX: Vollständige Immobiliensteuer pro 10.000 Dollar
# - PTRATIO: Schüler-Lehrer-Verhältnis nach Stadtteilen
# - B: Anteil an Afroamerikanern im Verhältnis zur Bevölkerung pro Stadt
# - LSTAT: Prozentsatz der Bevölkerung mit niedrigem sozioökonomischem Status
# - MEDV: Medianwert von Eigentumswohnungen in 1000er Dollar

# %% [markdown]
# ## Analyse des Datensatzes

# %%
# Erstellen der Korrelationsmatrix
corr_matrix = df.corr()

# Ausgabe der Korrelationsmatrix
print(corr_matrix)
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
# Erstellen der Heatmap
sns.heatmap(corr_matrix, cmap='coolwarm')

# Anpassen der Darstellung
plt.title('Korrelationsmatrix')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.show()

# %%
plt.scatter(df['rm'], df['medv'])
plt.xlabel('Durchschnittliche Anzahl der Zimmer pro Wohneinheit')
plt.ylabel('Hauspreis in Tausend US-Dollar')
plt.show()

# %%
plt.hist(df['medv'], bins=50)
plt.xlabel('Hauspreis in Tausend US-Dollar')
plt.ylabel('Anzahl der Wohneinheiten')
plt.show()

# %% [markdown]
# ## Durchführen und Visualisierung der lin. Regression
#
# $a = \frac{n\sum_{i=1}^n x_i y_i - \sum_{i=1}^n x_i \sum_{i=1}^n y_i}{n\sum_{i=1}^n x_i^2 - (\sum_{i=1}^n x_i)^2}$
#
# $b = \frac{\sum_{i=1}^n y_i - a\sum_{i=1}^n x_i}{n}$

# %% [markdown]
# ## Übung

# %%
x=[4,6,8,10,12]
y=[10,20,24,32,45]
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### Überprüfen der berechneten Werte

# %%
a=2 # Ihr berechneter Wert für a
b=4 # Ihr berechneter Wert für b
x=[4,6,8,10,12]
y=[10,20,24,32,45]
gx = [4, 12]
gy = [a*4+b, a*12+b]
plt.plot(gx, gy,color="red")
plt.scatter(x, y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

x = np.array([[4], [6], [8], [10], [12]])
y = np.array([10, 20, 24, 32, 45])

model = LinearRegression()
model.fit(x, y)

a = model.coef_[0]
b = model.intercept_

print(f"Parameter a: {a:.2f}")
print(f"Parameter b: {b:.2f}")

gx = [4, 12]
gy = [a*4+b, a*12+b]
plt.plot(gx, gy,color="red")
plt.scatter(x, y)
plt.show()
# Out:
# Parameter a: 4.10
# Parameter b: -6.60

# %%
model.fit(df[['rm']], df["medv"])

a = model.coef_[0]
b = model.intercept_
print(f"Parameter a: {a:.2f}")
print(f"Parameter b: {b:.2f}")
# Out:
# Parameter a: 9.10
# Parameter b: -34.67

# %%
mi=df["rm"].min();
ma=df["rm"].max();
x = [mi, ma]
y = [a*mi+b, a*ma+b]
 
plt.plot(x, y,color="red")
plt.ylabel('Einige Werte')
plt.scatter(df['rm'], df['medv'])
plt.xlabel('Durchschnittliche Anzahl der Zimmer pro Wohneinheit')
plt.ylabel('Hauspreis in Tausend US-Dollar')
plt.show()

# %% [markdown]
# ## Durchführen einer reg. Analyse

# %% [markdown]
# ### Daten aufteilen in Trainigsdaten und Testdaten

# %%
from sklearn.model_selection import train_test_split
feature_names=["rm","b","dis"]
X_train, X_test, y_train, y_test = train_test_split(df[feature_names], df['medv'], test_size=0.2, random_state=0)

# %% [markdown]
# ### Führe eine lineare Regression durch

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Auswertung der Vorhersage
#
# Der R^2-Wert wird als Maß für die Genauigkeit der Vorhersagen verwendet. Je höher der R^2-Wert, desto besser die Vorhersage.

# %%
from sklearn.metrics import r2_score

y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)

print('R^2: ', r2)
# Out:
# R^2:  0.4365705317143229

# %% [markdown]
# ## Eine Vorhersage erstellen
#
# Anhand eines Datensatzes kann nun ein Ergebnis vorhergesagt werden

# %%
print (df.iloc[6])
dp = pd.DataFrame(df.iloc[6]).T
col = dp.loc[:,["rm","b","dis"]]
model.predict(col)
# Out:
# crim         0.08829
# zn          12.50000
# indus        7.87000
# chas         0.00000
# nox          0.52400
# rm           6.01200
# age         66.60000
# dis          5.56050
# rad          5.00000
# tax        311.00000
# ptratio     15.20000
# b          395.60000
# lstat       12.43000
# medv        22.90000
# Name: 6, dtype: float64
# array([21.67040245])
